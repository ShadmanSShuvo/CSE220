# %%
import numpy as np

# %%
x = np.array([1,2,3,4,5,5])

# %%
x == 5
# Out:
# array([False, False, False, False,  True,  True])

# %%
print(np.where(x == 5)[0][1])
# Out:
# 5

# %%
mask1 = (x >= 3) & (x <= 4)
print(mask1)
x[mask1]
# Out:
# [False False  True  True False False]
# array([3, 4])

# %%
y = np.array([1,1,3,3,3,3])

# %%
y[mask1]
# Out:
# array([3, 3])

# %%
x[mask1] = [1,2]

# %%
print(x)
# Out:
# [1 2 1 2 5 5]

# %%
x = [1,2,3,4,5,6]
y = [1,2.000,3,4.000,5,6]
print(np.allclose(x,y))
# Out:
# True
